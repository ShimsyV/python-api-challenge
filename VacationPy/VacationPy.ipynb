# %% [markdown]
# ## VacationPy
#
# Looking to go for a vacation? Lets look for an ideal location and find a hotel.

# %% [markdown]
# ##### Import dependencies

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from config import (gkey, api_key)

# %% [markdown]
# #### Fetch CSV file from WeatherPy Folder

# %%
weather_data_to_load = "../WeatherPy/Output/CityWeatherData.csv"
weather_data = pd.read_csv(weather_data_to_load)
dropna_weather_data = weather_data.dropna()
dropna_weather_data.head(20)
# Out:
#                City Country  Cloudiness  Humidity  Latitude  Longitude  \
# 0          matagami      CA           1        71     49.75     -77.63
# 1     alice springs      AU          90        27    -23.70     133.88
# 2         caravelas      BR          29        62    -17.71     -39.25
# 3       east london      ZA          20        72    -33.02      27.91
# 4   bambous virieux      MU          75        77    -20.34      57.76
# 5              hami      CN         100        21     42.80      93.45
# 6       tuktoyaktuk      CA          90        92     69.45    -133.04
# 7   arraial do cabo      BR          20        74    -22.97     -42.03
# 8      listvyanskiy      RU         100        70     54.44      83.50
# 9          hermanus      ZA          39        70    -34.42      19.23
# 10    east valencia      PH         100        84     10.67     122.71
# 11    kazachinskoye      RU          61        89     57.70      93.28
# 12         olafsvik      IS          49        71     64.89     -23.71
# 13    ponta delgada      PT          20        43     37.73     -25.67
# 14        jamestown      SH          82        85    -15.94      -5.72
# 15           yining      CN         100        93     29.04     114.56
# 16          te anau      NZ          75        86    -45.42     167.72
# 17       carutapera      BR          75        65     -1.20     -46.02
# 18             hofn      IS           0        59     64.25     -15.21
# 19         tasiilaq      GL          90        94     65.61     -37.64
#
#     Max Temp  Windspeed
# 0      50.00      11.41
# 1      73.40       6.93
# 2      81.59      10.18
# 3      59.00       9.17
# 4      66.99      12.75
# 5      68.34       6.93
# 6      30.20      11.41
# 7      78.80      11.41
# 8      53.55       8.14
# 9      55.99       1.01
# 10     80.08      11.25
# 11     49.55       5.37
# 12     44.37       9.22
# 13     71.60      12.75
# 14     60.93      22.88
# 15     68.99       1.14
# 16     37.40       7.40
# 17     84.90      11.99
# 18     51.40       7.25
# 19     37.40      24.16

# %% [markdown]
# ##### Configure gmaps

# %%
gmaps.configure(api_key=gkey)

# %% [markdown]
# #####  Create a new variable to contain Latitude and Longitude and another new variable to contain the Humidity

# %%
locations = dropna_weather_data[["Latitude", "Longitude"]]

humidity = dropna_weather_data["Humidity"].astype(float)

# %% [markdown]
# ##### Create a Humidity heatmap layer

# %%
# Create the mapping figure
fig = gmaps.figure()

# Create the heatmap layer using locations and poverty_rate
heat_layer = gmaps.heatmap_layer(locations, weights=humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius=0.9)
# Add heatmap layer to figure
fig.add_layer(heat_layer)

# Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
